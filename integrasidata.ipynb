# %% [markdown]
# <a href="https://colab.research.google.com/github/zlfaris/Data-Mining-1/blob/main/integrasidata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Akses langsung dari Google Sheets (ubah export ke CSV)
sheet_url = "https://docs.google.com/spreadsheets/d/1YezL7SJCypFn9uWbeDSuhSUhaTBQU_z2/export?format=csv"
data = pd.read_csv(sheet_url)

# Simpan hasil integrasi
data.to_csv("data_integration.csv", index=False)
data.head()
# Out:
#   Laporan Penjualan  Unnamed: 1          Unnamed: 2  \
# 0         Tgl_Order    8/1/2025                 NaN
# 1        No.Faktur   Tgl Order                Sales
# 2        VRD25GAJGB    8/1/2025  Sahrul ( Prapani )
# 3        VRD25GAJMP    8/1/2025   Sales B2B Campina
# 4        VRD25GAOOM    8/1/2025  Sahrul ( Prapani )
#
#                      Unnamed: 3         Unnamed: 4           Unnamed: 5  \
# 0                           NaN                NaN                  NaN
# 1                     Pelanggan  Jumlah Bruto (Rp)  Total Discount (Rp)
# 2                     ALFA MIDI         67.273.668            3.652.960
# 3  INDOMARET FRVE - SUNGAI POSO            942.400              235.600
# 4   MATAHARI HYPERMART - MAMUJU          1.086.389                    0
#
#           Unnamed: 6   Unnamed: 7   Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0                NaN          NaN          NaN        NaN         NaN
# 1  Jumlah Netto (Rp)  Retur (Rp)   Total (Rp)       DiscD      DiscC
# ...
